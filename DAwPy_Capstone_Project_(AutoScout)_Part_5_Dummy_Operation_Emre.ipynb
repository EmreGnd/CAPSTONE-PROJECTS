# %% [markdown]
# # Dummy Operation

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

import warnings 
warnings.filterwarnings("ignore") 
warnings.warn("this will not show")

# %matplotlib inline

plt.rcParams["figure.figsize"] = (10,6)

sns.set_style("whitegrid") 
pd.set_option('display.float_format', lambda x: '%.3f' % x)

pd.options.display.max_rows = 150 
pd.options.display.max_columns = 100
import json
import regex as re
from datetime import date
from datetime import datetime
from datetime import timedelta

# %%
df = pd.read_csv("final_scout_not_dummy.csv")
df.head(10).T
# Out:
#                                                                        0  \
# make_model                                                       Audi A1
# body_type                                                         Sedans
# price                                                              14640
# vat                                                       VAT deductible
# km                                                             83450.000
# Type                                                                Used
# Body Color                                                         Black
# Paint Type                                                      Metallic
# Gearing Type                                                   Automatic
# Cylinders                                                          4.000
# Fuel                                                              Diesel
# Comfort & Convenience  Air conditioning,Cruise control,Electrical sid...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12168 entries, 0 to 12167
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   make_model             12168 non-null  object
#  1   body_type              12168 non-null  object
#  2   price                  12168 non-null  int64
#  3   vat                    12168 non-null  object
#  4   km                     12168 non-null  float64
#  5   Type                   12168 non-null  object
#  6   Body Color             12168 non-null  object
#  7   Paint Type             12168 non-null  object
#  8   Gearing Type           12168 non-null  object
#  9   Cylinders              12168 non-null  float64
#  10  Fuel                   12168 non-null  object
#  11  Comfort & Convenience  12168 non-null  object
#  12  Entertainment & Media  12168 non-null  object
#  13  Extras                 12168 non-null  object
# ...

# %%
df.shape
# Out:
# (12168, 32)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # Make & Model

# %%
one_hot = pd.get_dummies(df, columns = ['make_model'])
df = one_hot
df
# Out:
#            body_type  price             vat        km            Type  \
# 0             Sedans  14640  VAT deductible 83450.000            Used
# 1             Sedans  14500  VAT deductible 73000.000            Used
# 2             Sedans  16790  VAT deductible 16200.000            Used
# 3             Sedans  15090  VAT deductible 63668.000            Used
# 4      Station wagon  16422  VAT deductible 62111.000            Used
# ...              ...    ...             ...       ...             ...
# 12163            Van  39980  VAT deductible   100.000  Pre-registered
# 12164            Van  39950  VAT deductible   100.000             New
# 12165            Van  39950  VAT deductible  1000.000             New
# 12166            Van  39875  VAT deductible    15.000  Pre-registered
# 12167            Van  39700  VAT deductible    10.000  Pre-registered
#
#       Body Color Paint Type Gearing Type  Cylinders    Fuel  \
# 0          Black   Metallic    Automatic      4.000  Diesel
# ...

# %% [markdown]
# # Body Type

# %%
one_hot = pd.get_dummies(df, columns = ['body_type'])
df = one_hot
df
# Out:
#        price             vat        km            Type Body Color Paint Type  \
# 0      14640  VAT deductible 83450.000            Used      Black   Metallic
# 1      14500  VAT deductible 73000.000            Used      Brown   Metallic
# 2      16790  VAT deductible 16200.000            Used      Black   Metallic
# 3      15090  VAT deductible 63668.000            Used      White   Metallic
# 4      16422  VAT deductible 62111.000            Used      White   Metallic
# ...      ...             ...       ...             ...        ...        ...
# 12163  39980  VAT deductible   100.000  Pre-registered      White   Metallic
# 12164  39950  VAT deductible   100.000             New      Black   Metallic
# 12165  39950  VAT deductible  1000.000             New       Grey   Metallic
# 12166  39875  VAT deductible    15.000  Pre-registered      White   Metallic
# 12167  39700  VAT deductible    10.000  Pre-registered       Grey   Metallic
#
#       Gearing Type  Cylinders    Fuel  \
# ...

# %% [markdown]
# # VAT

# %%
one_hot = pd.get_dummies(df, columns = ['vat'])
df = one_hot
df
# Out:
#        price        km            Type Body Color Paint Type Gearing Type  \
# 0      14640 83450.000            Used      Black   Metallic    Automatic
# 1      14500 73000.000            Used      Brown   Metallic    Automatic
# 2      16790 16200.000            Used      Black   Metallic    Automatic
# 3      15090 63668.000            Used      White   Metallic    Automatic
# 4      16422 62111.000            Used      White   Metallic    Automatic
# ...      ...       ...             ...        ...        ...          ...
# 12163  39980   100.000  Pre-registered      White   Metallic    Automatic
# 12164  39950   100.000             New      Black   Metallic    Automatic
# 12165  39950  1000.000             New       Grey   Metallic    Automatic
# 12166  39875    15.000  Pre-registered      White   Metallic    Automatic
# 12167  39700    10.000  Pre-registered       Grey   Metallic    Automatic
#
#        Cylinders    Fuel                              Comfort & Convenience  \
# ...

# %% [markdown]
# # Type

# %%
one_hot = pd.get_dummies(df, columns = ['Type'])
df = one_hot
df
# Out:
#        price        km Body Color Paint Type Gearing Type  Cylinders    Fuel  \
# 0      14640 83450.000      Black   Metallic    Automatic      4.000  Diesel
# 1      14500 73000.000      Brown   Metallic    Automatic      3.000  Diesel
# 2      16790 16200.000      Black   Metallic    Automatic      3.000  Diesel
# 3      15090 63668.000      White   Metallic    Automatic      3.000  Diesel
# 4      16422 62111.000      White   Metallic    Automatic      4.000  Diesel
# ...      ...       ...        ...        ...          ...        ...     ...
# 12163  39980   100.000      White   Metallic    Automatic      4.000  Diesel
# 12164  39950   100.000      Black   Metallic    Automatic      4.000  Diesel
# 12165  39950  1000.000       Grey   Metallic    Automatic      4.000  Diesel
# 12166  39875    15.000      White   Metallic    Automatic      4.000  Diesel
# 12167  39700    10.000       Grey   Metallic    Automatic      4.000  Diesel
#
# ...

# %% [markdown]
# # Body_Color

# %%
one_hot = pd.get_dummies(df, columns = ['Body Color'])
df = one_hot
df
# Out:
#        price        km Paint Type Gearing Type  Cylinders    Fuel  \
# 0      14640 83450.000   Metallic    Automatic      4.000  Diesel
# 1      14500 73000.000   Metallic    Automatic      3.000  Diesel
# 2      16790 16200.000   Metallic    Automatic      3.000  Diesel
# 3      15090 63668.000   Metallic    Automatic      3.000  Diesel
# 4      16422 62111.000   Metallic    Automatic      4.000  Diesel
# ...      ...       ...        ...          ...        ...     ...
# 12163  39980   100.000   Metallic    Automatic      4.000  Diesel
# 12164  39950   100.000   Metallic    Automatic      4.000  Diesel
# 12165  39950  1000.000   Metallic    Automatic      4.000  Diesel
# 12166  39875    15.000   Metallic    Automatic      4.000  Diesel
# 12167  39700    10.000   Metallic    Automatic      4.000  Diesel
#
#                                    Comfort & Convenience  \
# 0      Air conditioning,Cruise control,Electrical sid...
# ...

# %% [markdown]
# # Gearing Type

# %%
one_hot = pd.get_dummies(df, columns = ['Gearing Type'])
df = one_hot
df
# Out:
#        price        km Paint Type  Cylinders    Fuel  \
# 0      14640 83450.000   Metallic      4.000  Diesel
# 1      14500 73000.000   Metallic      3.000  Diesel
# 2      16790 16200.000   Metallic      3.000  Diesel
# 3      15090 63668.000   Metallic      3.000  Diesel
# 4      16422 62111.000   Metallic      4.000  Diesel
# ...      ...       ...        ...        ...     ...
# 12163  39980   100.000   Metallic      4.000  Diesel
# 12164  39950   100.000   Metallic      4.000  Diesel
# 12165  39950  1000.000   Metallic      4.000  Diesel
# 12166  39875    15.000   Metallic      4.000  Diesel
# 12167  39700    10.000   Metallic      4.000  Diesel
#
#                                    Comfort & Convenience  \
# 0      Air conditioning,Cruise control,Electrical sid...
# 1      Air suspension,Armrest,Auxiliary heating,Elect...
# 2      Air conditioning,Armrest,Automatic climate con...
# 3      Air conditioning,Armrest,Automatic climate con...
# ...

# %% [markdown]
# # Fuel

# %%
one_hot = pd.get_dummies(df, columns = ['Fuel'])
df = one_hot
df
# Out:
#        price        km Paint Type  Cylinders  \
# 0      14640 83450.000   Metallic      4.000
# 1      14500 73000.000   Metallic      3.000
# 2      16790 16200.000   Metallic      3.000
# 3      15090 63668.000   Metallic      3.000
# 4      16422 62111.000   Metallic      4.000
# ...      ...       ...        ...        ...
# 12163  39980   100.000   Metallic      4.000
# 12164  39950   100.000   Metallic      4.000
# 12165  39950  1000.000   Metallic      4.000
# 12166  39875    15.000   Metallic      4.000
# 12167  39700    10.000   Metallic      4.000
#
#                                    Comfort & Convenience  \
# 0      Air conditioning,Cruise control,Electrical sid...
# 1      Air suspension,Armrest,Auxiliary heating,Elect...
# 2      Air conditioning,Armrest,Automatic climate con...
# 3      Air conditioning,Armrest,Automatic climate con...
# 4      Air conditioning,Armrest,Automatic climate con...
# ...                                                  ...
# ...

# %%
df.shape
# Out:
# (12168, 70)

# %%
df = pd.get_dummies(df)
df.sample(50)
# Out:
#        price         km  Cylinders  Gears  Previous_Owners   hp_kW  \
# 5605   18690  23900.000      4.000  6.000            1.000 110.000
# 8687   14800  94800.000      4.000  6.000            1.000 125.000
# 7812    9900  44000.000      4.000  5.000            1.000  51.000
# 3      15090  63668.000      3.000  6.000            1.000  85.000
# 3217   19490  44400.000      4.000  6.000            1.000  81.000
# 9806   29350     10.000      4.000  6.000            1.000 147.000
# 8275   10689     10.000      4.000  5.000            1.000  51.000
# 11081   9900  44451.000      4.000  5.000            1.000  66.000
# 2404   15700  88000.000      4.000  7.000            1.000  81.000
# 7201    7900  13160.000      4.000  5.000            1.000  51.000
# 1478   16700  10975.000      4.000  5.000            1.000  85.000
# 2434   15490  53994.000      4.000  6.000            1.000  81.000
# 4738   14490  47000.000      4.000  5.000            1.000 100.000
# ...

# %%
df.to_csv("final_scout_dummy.csv", encoding='utf-8', index=False)
